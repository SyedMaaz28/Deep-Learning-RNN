# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## Sentence

sent = ['I am a good boy','The food is good',
        'I am a best disco dancer','how are you doing today',
        'bottle of water','wheather is good today','Honesty is the best policy']

# %%
sent
# Out:
# ['I am a good boy',
#  'The food is good',
#  'I am a best disco dancer',
#  'how are you doing today',
#  'bottle of water',
#  'wheather is good today',
#  'Honesty is the best policy']

# %%
## Define vocabulary size
vocab_size = 10000

# %%
## one hot encoding
one_hot_repr = [one_hot(sentence, vocab_size) for sentence in sent]
one_hot_repr
# Out:
# [[6754, 7514, 9294, 3427, 602],
#  [1253, 7507, 5513, 3427],
#  [6754, 7514, 9294, 1114, 882, 9141],
#  [8903, 6475, 2434, 5065, 3991],
#  [1703, 8351, 9451],
#  [1751, 5513, 3427, 3991],
#  [9656, 5513, 1253, 1114, 7998]]

# %%
## Word Embedding
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import pad_sequences

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0, 6754, 7514, 9294, 3427,  602],
#        [   0,    0,    0,    0, 1253, 7507, 5513, 3427],
#        [   0,    0, 6754, 7514, 9294, 1114,  882, 9141],
#        [   0,    0,    0, 8903, 6475, 2434, 5065, 3991],
#        [   0,    0,    0,    0,    0, 1703, 8351, 9451],
#        [   0,    0,    0,    0, 1751, 5513, 3427, 3991],
#        [   0,    0,    0, 9656, 5513, 1253, 1114, 7998]], dtype=int32)

# %%
# Feature Representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(vocab_size, dim, input_length=sent_length))
model.compile('adam', 'mse')
# Out:
# 2025-07-04 14:54:34.671991: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-07-04 14:54:34.672457: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-07-04 14:54:34.672585: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-07-04 14:54:34.673667: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-04 14:54:34.674960: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 8, 10)             100000
#
# ...
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 2025-07-04 15:23:35.397346: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 568ms/step
# array([[[-4.43650149e-02, -2.16848012e-02,  1.35303400e-02,
#          -1.79264061e-02,  1.91978700e-02, -4.83121872e-02,
#           3.09740640e-02,  3.98889817e-02, -4.74641919e-02,
#          -3.80863994e-03],
#         [-4.43650149e-02, -2.16848012e-02,  1.35303400e-02,
#          -1.79264061e-02,  1.91978700e-02, -4.83121872e-02,
#           3.09740640e-02,  3.98889817e-02, -4.74641919e-02,
#          -3.80863994e-03],
#         [-4.43650149e-02, -2.16848012e-02,  1.35303400e-02,
#          -1.79264061e-02,  1.91978700e-02, -4.83121872e-02,
#           3.09740640e-02,  3.98889817e-02, -4.74641919e-02,
#          -3.80863994e-03],
#         [-3.06325443e-02, -3.42746750e-02,  4.61932682e-02,
#           4.49408777e-02,  3.82459499e-02,  2.68594734e-02,
# ...
